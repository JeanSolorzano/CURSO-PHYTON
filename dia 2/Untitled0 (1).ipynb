# %%
#estructuras de datos
listas =[1,2,3,4] 


tuplas= (1,2,3,4)

conjuntos = {1,2,3,4,1}

#bucles imprimir uno por uno
listas = [1,2,3,4,3]


#bucles for y bucles while
for elemnto in listas:
    print(elemnto)

#con palabras una por una en fila

palabra = 'hola'


#palabras reseervadas

#break
#while


#que imprima solamente los repetidos

for elemnto in listas:
    print(elemnto)



#bucles while
posicion = 0

while posicion < 6:
    elemnto = listas[posicion]
    print(elemnto)
    posicion = posicion +1
# Out:
# 1
# 2
# 3
# 4
# 3
# 1
# 2
# 3
# 4
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-481b2723d1e7> in <module>
#      37
#      38 while posicion < 6:
# ---> 39     elemnto = list[posicion]
#      40     print(elemnto)
#      41     posicion = posicion +1
#
# TypeError: 'type' object is not subscriptable
